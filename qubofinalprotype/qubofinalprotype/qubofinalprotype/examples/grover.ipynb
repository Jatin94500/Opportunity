# %% [markdown]
# # Grover's Algorithm (toy example)
# A small Grover example using `qubo`.]
# :
# ,
# : {
# :
# },
# : [
# ,
# ,
#
# :
# ,
# : {
# :
# },
# : [
# ,
# ,
#
# ,
# 1
# ,
#
# 1
# ,
#
# ,
# 1
# ,
# ,
# ,
